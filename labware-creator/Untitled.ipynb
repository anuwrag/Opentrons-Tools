# %%
import matplotlib.pyplot as plt
import numpy as np
# # Rectangle
plt.gca().add_patch(plt.Rectangle((0.1, 0.1), 0.5, 0.5, fill=False))

# Circle
plt.gca().add_patch(plt.Circle((0.7, 0.7), 0.2, fill=False))


plt.axis('scaled')
plt.show()

# %%
import json

# %%
f = open('Modified12x125ml_update copy.json', 'r')
data = json.load(f)

# %%
data['cornerOffsetFromSlot']
# Out:
# {'x': -75, 'y': -143, 'z': 0}

# %%
import matplotlib.pyplot as plt
import numpy as np
import json 

f = '''{
  "ordering": [
    [
      "A1",
      "B1",
      "C1"
    ],
    [
      "A2",
      "B2",
      "C2"
    ],
    [
      "A3",
      "B3",
      "C3"
    ],
    [
      "A4",
      "B4",
      "C4"
    ]
  ],
  "brand": {
    "brand": "Corning",
    "brandId": [
      "3650",
      "3916",
      "3915"
    ],
    "links": [
      ""
    ]
  },
  "metadata": {
    "displayName": "Opentrons Custom 12x125 mL bottle rack",
    "displayCategory": "wellPlate",
    "displayVolumeUnits": "µL",
    "tags": []
  },
  "dimensions": {
    "xDimension": 247.5,
    "yDimension": 213,
    "zDimension": 91
  },
  "wells": {
    "A1": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 11.75,
      "y": 203,
      "z": 3.55
    },
    "B1": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 11.75,
      "y": 133,
      "z": 3.55
    },
    "C1": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 11.75,
      "y": 63,
      "z": 3.55
    },
    "A2": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 68.75,
      "y": 203,
      "z": 3.55
    },
    "B2": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 68.75,
      "y": 133,
      "z": 3.55
    },
    "C2": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 68.75,
      "y": 63,
      "z": 3.55
    },
    "A3": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 125.75,
      "y": 203,
      "z": 3.55
    },
    "B3": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 125.75,
      "y": 133,
      "z": 3.55
    },
    "C3": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 125.75,
      "y": 63,
      "z": 3.55
    },
    "A4": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 182.75,
      "y": 203,
      "z": 3.55
    },
    "B4": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 182.75,
      "y": 133,
      "z": 3.55
    },
    "C4": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 182.75,
      "y": 63,
      "z": 3.55
    }
  },
  "groups": [
    {
      "metadata": {
        "wellBottomShape": "flat"
      },
      "wells": [
        "A1",
        "B1",
        "C1",
        "A2",
        "B2",
        "C2",
        "A3",
        "B3",
        "C3",
        "A4",
        "B4",
        "C4"
      ]
    }
  ],
  "parameters": {
    "format": "96Standard",
    "isTiprack": false,
    "isMagneticModuleCompatible": false,
    "loadName": "opentrons_12_wellplate_250000ul_flat"
  },
  "namespace": "custom_beta",
  "version": 1,
  "schemaVersion": 2,
  "cornerOffsetFromSlot": {
    "x": -75,
    "y": -143,
    "z": 0
  }
}'''
data = json.loads(f)

off = data['cornerOffsetFromSlot']
plt.xlim(0, data['dimensions']['xDimension']-off['x'])  # Adjust as needed
plt.ylim(0, data['dimensions']['yDimension']-off['y'])   # Adjust as needed

for well in np.ravel(data['ordering']):    
    x = data['wells'][well]['x'];
    y = data['wells'][well]['y'];
    d = data['wells'][well]['diameter']/2;
    plt.gca().add_patch(plt.Circle((x-off['x'], y-off['y']), d, fill=False))
plt.axis('equal')
# Out:
# (np.float64(58.95), np.float64(285.55), np.float64(179.75), np.float64(372.25))

# %%
plt.axis()
plt.show()

# %%
plt.gca().add_patch(plt.Circle((0.222,0.33), 0.22, fill=False))

# %%
m = '''{
  "ordering": [
    [
      "A1",
      "B1",
      "C1"
    ],
    [
      "A2",
      "B2",
      "C2"
    ],
    [
      "A3",
      "B3",
      "C3"
    ],
    [
      "A4",
      "B4",
      "C4"
    ]
  ],
  "brand": {
    "brand": "Corning",
    "brandId": [
      "3650",
      "3916",
      "3915"
    ],
    "links": [
      ""
    ]
  },
  "metadata": {
    "displayName": "Opentrons Custom 12x125 mL bottle rack",
    "displayCategory": "wellPlate",
    "displayVolumeUnits": "µL",
    "tags": []
  },
  "dimensions": {
    "xDimension": 247.5,
    "yDimension": 213,
    "zDimension": 91
  },
  "wells": {
    "A1": {
      "depth": 89,
      "shape": "circular",
      "diameter": 159,
      "totalLiquidVolume": 250000,
      "x": 11.75,
      "y": 203,
      "z": 3.55
    },
    "B1": {
      "depth": 89,
      "shape": "circular",
      "diameter": 160,
      "totalLiquidVolume": 250000,
      "x": 11.75,
      "y": 133,
      "z": 3.55
    },
    "C1": {
      "depth": 89,
      "shape": "circular",
      "diameter": 200,
      "totalLiquidVolume": 250000,
      "x": 11.75,
      "y": 63,
      "z": 3.55
    },
    "A2": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 68.75,
      "y": 203,
      "z": 3.55
    },
    "B2": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 68.75,
      "y": 133,
      "z": 3.55
    },
    "C2": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 68.75,
      "y": 63,
      "z": 3.55
    },
    "A3": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 125.75,
      "y": 203,
      "z": 3.55
    },
    "B3": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 125.75,
      "y": 133,
      "z": 3.55
    },
    "C3": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 125.75,
      "y": 63,
      "z": 3.55
    },
    "A4": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 182.75,
      "y": 203,
      "z": 3.55
    },
    "B4": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 182.75,
      "y": 133,
      "z": 3.55
    },
    "C4": {
      "depth": 89,
      "shape": "circular",
      "diameter": 35,
      "totalLiquidVolume": 250000,
      "x": 182.75,
      "y": 63,
      "z": 3.55
    }
  },
  "groups": [
    {
      "metadata": {
        "wellBottomShape": "flat"
      },
      "wells": [
        "A1",
        "B1",
        "C1",
        "A2",
        "B2",
        "C2",
        "A3",
        "B3",
        "C3",
        "A4",
        "B4",
        "C4"
      ]
    }
  ],
  "parameters": {
    "format": "96Standard",
    "isTiprack": false,
    "isMagneticModuleCompatible": false,
    "loadName": "opentrons_12_wellplate_250000ul_flat"
  },
  "namespace": "custom_beta",
  "version": 1,
  "schemaVersion": 2,
  "cornerOffsetFromSlot": {
    "x": -75,
    "y": -143,
    "z": 0
  }
}'''

# %%
json.loads(m)
# Out:
# {'ordering': [['A1', 'B1', 'C1'],
#   ['A2', 'B2', 'C2'],
#   ['A3', 'B3', 'C3'],
#   ['A4', 'B4', 'C4']],
#  'brand': {'brand': 'Corning',
#   'brandId': ['3650', '3916', '3915'],
#   'links': ['']},
#  'metadata': {'displayName': 'Opentrons Custom 12x125 mL bottle rack',
#   'displayCategory': 'wellPlate',
#   'displayVolumeUnits': 'µL',
#   'tags': []},
#  'dimensions': {'xDimension': 247.5, 'yDimension': 213, 'zDimension': 91},
#  'wells': {'A1': {'depth': 89,
#    'shape': 'circular',
#    'diameter': 159,
#    'totalLiquidVolume': 250000,
#    'x': 11.75,
#    'y': 203,
#    'z': 3.55},
#   'B1': {'depth': 89,
#    'shape': 'circular',
#    'diameter': 160,
#    'totalLiquidVolume': 250000,
#    'x': 11.75,
#    'y': 133,
#    'z': 3.55},
#   'C1': {'depth': 89,
#    'shape': 'circular',
#    'diameter': 200,
#    'totalLiquidVolume': 250000,
#    'x': 11.75,
#    'y': 63,
#    'z': 3.55},
#   'A2': {'depth': 89,
#    'shape': 'circular',
#    'diameter': 35,
# ...
